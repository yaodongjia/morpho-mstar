# %% [markdown]
# # Creating a simple CNN
#
# This model has only a few layers, and does not make use of additional information (e.g. distance).

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os

from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt

if os.getcwd().endswith('notebooks'):
    os.chdir('..')
    print('Changed directory to', os.getcwd())
# Out:
# Changed directory to E:\workspace\morpho-mstar

# %% [markdown]
# # Load data

# %%
from morphoml import load_npy

dsets = ['train', 'val', 'test']
npix = 69
ntrain = 10000
d_data = {}

for dset in dsets:
    d_data[dset] = {}
    imgs, names = load_npy(dset, npix=npix, ntrain=10000)
    d_data[dset]['imgs'] = np.expand_dims(imgs, axis=-1)
    d_data[dset]['names'] = names

# %%
print(d_data['train']['imgs'].shape, d_data['val']['imgs'].shape, d_data['test']['imgs'].shape,
      d_data['train']['imgs'].dtype)
# Each image is scaled to [-1, 1]
print(np.min(d_data['train']['imgs'][0, :]), np.max(d_data['train']['imgs'][0, :]))
# Names contains a unique 64-bit identifier for each galaxy (called "objid")
print(d_data['train']['names'].shape, d_data['train']['names'].dtype)
d_data['train']['names'][:5]
# Out:
# (10000, 69, 69, 1) (2500, 69, 69, 1) (5000, 69, 69, 1) float32
# -1.0 1.0
# (10000,) int64
# array([1237657611265507490, 1237661852004253738, 1237662305125204183,
#        1237659324942712960, 1237657858221801565], dtype=int64)

# %%
# The metadata is indexed by the objid
df_meta = pd.read_csv('./data/metadata/metadata.tsv', sep='\t', index_col=0)
print(df_meta.shape)
df_meta.head()
# Out:
# (73627, 4)
#                           M/L           L_g  distance_Mpc  galsize_kpc
# SDSS_ID
# 1237662301367173202  2.398229  8.880467e+09    326.142854    48.655727
# 1237662301905813735  0.974585  7.007162e+09    293.571417    38.145197
# 1237662534360301834  0.678322  1.047446e+10    167.142861    30.677076
# 1237662500543987740  1.574709  1.748155e+10    282.000016    46.129129
# 1237662474235085097  1.076603  9.267565e+09    291.857134    43.540800

# %%
for dset in dsets:
    d_data[dset]['M/L'] = df_meta.loc[d_data[dset]['names'], 'M/L'].values

# %% [markdown]
# # Build and train model

# %%
from tensorflow.keras import layers

model = tf.keras.Sequential()
model.add(layers.Conv2D(32, (5, 5), activation='relu', input_shape=(npix, npix, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (4, 4), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.GlobalMaxPooling2D())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='relu'))

model.compile(optimizer='nadam', loss='mean_squared_error', metrics=['mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 65, 65, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 64)        32832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# global_max_pooling2d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 321,665
# Trainable params: 321,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create datasets
import tensorflow_addons as tfa

batch_size = 32
AUTOTUNE = tf.data.experimental.AUTOTUNE

for dset in dsets:
    d_data[dset]['xy_dataset'] = tf.data.Dataset.from_tensor_slices(
                                        (d_data[dset]['imgs'], d_data[dset]['M/L'])
                                )

def convert_image(image):
    # Cast and normalize the image to [0,1]
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image

def augment_image(image):
    add_pix = 10
    npix = image.shape[1]
    image = convert_image(image)
    # to [0, 2], since it automatically pads with zeros
    image = image + 1
    # Add padding (to translate later)
    image = tf.image.resize_with_crop_or_pad(image, npix + add_pix, npix + add_pix)
    # Rotate all images in batch with same, uniformly chosen angle
    random_angles = tf.random.uniform(shape = (), minval=-np.pi, maxval=np.pi)
    image = tfa.image.rotate(image, random_angles)
    # Crop back to needed format
    image = tf.image.random_crop(image, size=[npix, npix, 1]) # Random crop back
    image = image - 1
    return image

def convert(image, label): return convert_image(image), label
def augment(image, label): return augment_image(image), label

augmented_train_batches = (
     d_data['train']['xy_dataset']
        .cache()
        .shuffle(ntrain // 4)
        .map(augment, num_parallel_calls=AUTOTUNE)
        .batch(batch_size)
        .prefetch(AUTOTUNE)
)
validation_batches = (
     d_data['val']['xy_dataset']
        .map(convert, num_parallel_calls=AUTOTUNE)
        .batch(batch_size)
)

# %%
tf.random.set_seed(42)
np.random.seed(42)

nepochs = 100
callbacks = [tf.keras.callbacks.EarlyStopping(min_delta=1e-4, patience=6,
                                              restore_best_weights=True),
             tf.keras.callbacks.ReduceLROnPlateau(factor=0.3, patience=3,
                                                  min_delta=1e-4, verbose=1)]
history = model.fit(augmented_train_batches, 
                    validation_data=validation_batches,
                    epochs=nepochs, 
                    callbacks=callbacks)
# Out:
# Train for 313 steps, validate for 79 steps
# Epoch 1/100
# 313/313 [==============================] - 6s 20ms/step - loss: 1.4681 - mse: 1.4687 - val_loss: 1.1937 - val_mse: 1.1871
# Epoch 2/100
# 313/313 [==============================] - 4s 12ms/step - loss: 1.2238 - mse: 1.2230 - val_loss: 1.2961 - val_mse: 1.2921
# Epoch 3/100
# 313/313 [==============================] - 4s 12ms/step - loss: 1.1552 - mse: 1.1560 - val_loss: 1.2933 - val_mse: 1.2880
# Epoch 4/100
# 313/313 [==============================] - 4s 12ms/step - loss: 1.1025 - mse: 1.1027 - val_loss: 1.0789 - val_mse: 1.0725
# Epoch 5/100
# 313/313 [==============================] - 4s 12ms/step - loss: 1.0441 - mse: 1.0435 - val_loss: 1.0834 - val_mse: 1.0753
# Epoch 6/100
# 313/313 [==============================] - 4s 12ms/step - loss: 1.0010 - mse: 1.0012 - val_loss: 0.9892 - val_mse: 0.9809
# Epoch 7/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9805 - mse: 0.9814 - val_loss: 1.0235 - val_mse: 1.0167
# Epoch 8/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9600 - mse: 0.9598 - val_loss: 0.9536 - val_mse: 0.9441
# Epoch 9/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9638 - mse: 0.9637 - val_loss: 0.9409 - val_mse: 0.9337
# Epoch 10/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9466 - mse: 0.9467 - val_loss: 0.9290 - val_mse: 0.9235
# Epoch 11/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9486 - mse: 0.9455 - val_loss: 0.9668 - val_mse: 0.9569
# Epoch 12/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9353 - mse: 0.9357 - val_loss: 0.9756 - val_mse: 0.9695
# Epoch 13/100
# 305/313 [============================>.] - ETA: 0s - loss: 0.9168 - mse: 0.9168
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9146 - mse: 0.9149 - val_loss: 0.9346 - val_mse: 0.9285
# Epoch 14/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8754 - mse: 0.8752 - val_loss: 0.8839 - val_mse: 0.8795
# Epoch 15/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8688 - mse: 0.8694 - val_loss: 0.8806 - val_mse: 0.8764
# Epoch 16/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8706 - mse: 0.8708 - val_loss: 0.8916 - val_mse: 0.8880
# Epoch 17/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8630 - mse: 0.8639 - val_loss: 0.8697 - val_mse: 0.8645
# Epoch 18/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8506 - mse: 0.8510 - val_loss: 0.9465 - val_mse: 0.9369
# Epoch 19/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8480 - mse: 0.8491 - val_loss: 0.8814 - val_mse: 0.8769
# Epoch 20/100
# 305/313 [============================>.] - ETA: 0s - loss: 0.8533 - mse: 0.8533
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8542 - mse: 0.8534 - val_loss: 0.8710 - val_mse: 0.8670
# Epoch 21/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8291 - mse: 0.8297 - val_loss: 0.8459 - val_mse: 0.8422
# Epoch 22/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8274 - mse: 0.8271 - val_loss: 0.8617 - val_mse: 0.8584
# Epoch 23/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8238 - mse: 0.8241 - val_loss: 0.8483 - val_mse: 0.8453
# Epoch 24/100
# 309/313 [============================>.] - ETA: 0s - loss: 0.8254 - mse: 0.8254
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8224 - mse: 0.8231 - val_loss: 0.8492 - val_mse: 0.8441
# Epoch 25/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8132 - mse: 0.8139 - val_loss: 0.8436 - val_mse: 0.8393
# Epoch 26/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8119 - mse: 0.8121 - val_loss: 0.8405 - val_mse: 0.8361
# Epoch 27/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8138 - mse: 0.8134 - val_loss: 0.8404 - val_mse: 0.8363
# Epoch 28/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8083 - mse: 0.8087 - val_loss: 0.8418 - val_mse: 0.8380
# Epoch 29/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8206 - mse: 0.8206 - val_loss: 0.8400 - val_mse: 0.8361
# Epoch 30/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8084 - mse: 0.8085 - val_loss: 0.8365 - val_mse: 0.8330
# Epoch 31/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8100 - mse: 0.8098 - val_loss: 0.8434 - val_mse: 0.8402
# Epoch 32/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8071 - mse: 0.8076 - val_loss: 0.8424 - val_mse: 0.8386
# Epoch 33/100
# 304/313 [============================>.] - ETA: 0s - loss: 0.8069 - mse: 0.8069
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8020 - mse: 0.8022 - val_loss: 0.8386 - val_mse: 0.8346
# Epoch 34/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8061 - mse: 0.8064 - val_loss: 0.8392 - val_mse: 0.8355
# Epoch 35/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8082 - mse: 0.8087 - val_loss: 0.8388 - val_mse: 0.8349
# Epoch 36/100
# 311/313 [============================>.] - ETA: 0s - loss: 0.8018 - mse: 0.8018
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8060 - mse: 0.8052 - val_loss: 0.8372 - val_mse: 0.8338

# %%
history_df = pd.DataFrame(history.history)
plt.plot(history_df['loss'], label='training_loss')
plt.plot(history_df['val_loss'], label='validation_loss')
_ = plt.legend()

# %%
for dset in dsets:
    d_data[dset]['y_pred'] = model.predict(d_data[dset]['xy_dataset']
                                            .map(convert, num_parallel_calls=AUTOTUNE)
                                            .batch(batch_size)).squeeze()

# %% [markdown]
# # Check results

# %%
def estimate_density(x, y, **kwargs):
    xy = np.vstack([x, y])
    kde = gaussian_kde(xy, **kwargs)
    z = kde(xy)
    # Sort the points by density, so that the densest points are plotted last
    idx = z.argsort()
    return x[idx], y[idx], z[idx]

def rmse(yt, yp):
    return np.sqrt(np.mean(np.square(yt - yp)))

def r2(yt, yp):
    ybar = np.mean(yt)
    return 1 - (np.sum(np.square(yt - yp)) / np.sum(np.square(yt - ybar)))

def plot_truevspred(dset='test'):
    y = d_data[dset]['M/L']
    y_pred = d_data[dset]['y_pred']
    rmse_val = rmse(y, y_pred)
    r2_val = r2(y, y_pred)
    
    xc, yc, c = estimate_density(y, y_pred)
    plt.rcParams['axes.labelsize'] = 20
    plt.rcParams['font.size'] = 10
    plt.figure(figsize=(10, 7))
    plt.scatter(xc, yc, c=c, alpha=0.35)
    plt.xlabel('True M/L')
    plt.ylabel('Predicted M/L')
    plt.plot([0, 8], [0, 8], 'k-')
    ax = plt.gca()
    fontsize = 24
    plt.text(0.05, 0.92, f'RMSE = {rmse_val:.3f}', transform=ax.transAxes,
             fontsize=fontsize)
    plt.text(0.05, 0.83, f'$R^2$ = {r2_val:.3f}', transform=ax.transAxes,
             fontsize=fontsize)
    
plot_truevspred()
